# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
data=pd.read_csv('Iris.csv')
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#     FlowerColour  YearCollected  MonthCollected  StigmaLegnth         Species
# 0         Purple           2003               2             2     Iris-setosa
# ...

# %%
X = data.drop(['YearCollected', 'MonthCollected'],axis=1)   #Feature Matrix
y = data["YearCollected"]

# %%
X
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#     FlowerColour  StigmaLegnth         Species
# 0         Purple             2     Iris-setosa
# 1         Orange             1     Iris-setosa
# ...

# %%
# Change from categorical to numerical
label_encoder = LabelEncoder()
X['FlowerColour'] = label_encoder.fit_transform(X['FlowerColour'])
X['Species'] = label_encoder.fit_transform(X['Species'])

# %%
X
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#      FlowerColour  StigmaLegnth  Species
# 0              13             2        0
# 1              11             1        0
# ...

# %%
# separate dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((105, 8), (45, 8))

# %%
X_train.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.722006     -0.333772       0.886490
# SepalLengthCm  0.722006       1.000000     -0.036240       0.884322
# SepalWidthCm  -0.333772      -0.036240      1.000000      -0.338924
# PetalLengthCm  0.886490       0.884322     -0.338924       1.000000
# PetalWidthCm   0.907744       0.832547     -0.286746       0.968533
# FlowerColour  -0.105425      -0.094597      0.213849      -0.159437
# StigmaLegnth  -0.015629       0.015014     -0.440990       0.133971
# Species        0.943134       0.789649     -0.357443       0.953991
#
#                PetalWidthCm  FlowerColour  StigmaLegnth   Species
# Id                 0.907744     -0.105425     -0.015629  0.943134
# SepalLengthCm      0.832547     -0.094597      0.015014  0.789649
# SepalWidthCm      -0.286746      0.213849     -0.440990 -0.357443
# PetalLengthCm      0.968533     -0.159437      0.133971  0.953991
# ...

# %%
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.8)
len(set(corr_features))
# Out:
# 3

# %%
corr_features
# Out:
# {'PetalLengthCm', 'PetalWidthCm', 'Species'}

# %%
X_train.drop(corr_features,axis=1)
X_test.drop(corr_features,axis=1)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  FlowerColour  StigmaLegnth
# 114  115            5.8           2.8            13             2
# 62    63            6.0           2.2            17            15
# 33    34            5.5           4.2            15             3
# 107  108            7.3           2.9            11             1
# 7      8            5.0           3.4            19             3
# 100  101            6.3           3.3            14             2
# 40    41            5.0           3.5            16             4
# 86    87            6.7           3.1             5            20
# 76    77            6.8           2.8             1            20
# 71    72            6.1           2.8             6            14
# 134  135            6.1           2.6             9             1
# 51    52            6.4           3.2            13            16
# 73    74            6.1           2.8             1            15
# ...

# %% [markdown]
# 1. What features did you manually dropped before applying the feature selection methods? Explain why.
#    - YearCollected and MonthCollected. They are not important to finding the correlation that focuses on Iris's features
# 2. Are there any common features selected across multiple methods?
#    - The ones in corr_features are those that are highly correlated with one another
# 3. Can you explain why certain features were selected based on their characteristics? (Optional) Visualize the importance of features using techniques like bar charts or heatmaps to make it easier to compare.
#    - The correlation threshold is set to 0.8, meaning that features with an absolute correlation coefficient greater than that will be considered highly correlated
