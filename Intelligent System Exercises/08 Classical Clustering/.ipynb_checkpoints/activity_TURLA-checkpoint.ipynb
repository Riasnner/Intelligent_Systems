# %%
# Import necessary libraries
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans, AgglomerativeClustering, SpectralClustering
from sklearn.metrics import adjusted_rand_score, silhouette_score
import skfuzzy.cluster as fuzz
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Generate a hypothetical dataset
X, y_true = make_blobs(n_samples=300, centers=4, random_state=42, cluster_std=1.0)

# %%
data = pd.read_csv('credit_card.csv',encoding='latin1', index_col=0)
data
# Out:
#              BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CUST_ID
# C10001     40.900749           0.818182      95.40              0.00
# C10002   3202.467416           0.909091       0.00              0.00
# C10003   2495.148862           1.000000     773.17            773.17
# C10004   1666.670542           0.636364    1499.00           1499.00
# C10005    817.714335           1.000000      16.00             16.00
# ...              ...                ...        ...               ...
# C19186     28.493517           1.000000     291.12              0.00
# C19187     19.183215           1.000000     300.00              0.00
# C19188     23.398673           0.833333     144.40              0.00
# C19189     13.457564           0.833333       0.00              0.00
# C19190    372.708075           0.666667    1093.25           1093.25
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# CUST_ID
# ...

# %%
plt.scatter(X[:, 0], X[:, 1], s=30)
plt.title("Generated Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %% [markdown]
# <h2>K-Means Algorithm</h2>

# %%
kmeans = KMeans(n_clusters=4, random_state=42)

# %%
Klabels = kmeans.fit_predict(X)
centroids = kmeans.cluster_centers_
# Out:
# C:\Users\Ashley\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# Evaluate clustering performance using Adjusted Rand Index
ari = adjusted_rand_score(y_true, Klabels)
silhouette_avg = silhouette_score(X, Klabels)

# Print Adjusted Rand Index
print(f"Adjusted Rand Index: {ari:.4f}")
print(f"Silhouette Score: {silhouette_avg:.4f}")
# Out:
# Adjusted Rand Index: 0.9911
# Silhouette Score: 0.7916

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, s=30, cmap='viridis', alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=200, label='Centroids')
plt.title("K-Means Clustering")
plt.xlabel("X")
plt.ylabel("y_true")
plt.legend()
plt.show()

# %% [markdown]
# <h2>Fuzzy C-Means Algorithm</h2>

# %%
# Apply Fuzzy C-Means clustering
n_clusters = 4
cntr, u, u0, d, jm, p, fpc = fuzz.cmeans(X.T, c=n_clusters, m=2, error=0.005, maxiter=1000)

# Get cluster memberships
FClabels = np.argmax(u, axis=0)

# %%
# Evaluate clustering performance using Adjusted Rand Index
ari = adjusted_rand_score(y_true, FClabels)
silhouette_avg = silhouette_score(X, FClabels)

# Print Adjusted Rand Index
print(f"Adjusted Rand Index: {ari:.4f}")
print(f"Silhouette Score: {silhouette_avg:.4f}")
# Out:
# Adjusted Rand Index: 0.9911
# Silhouette Score: 0.7916

# %%
# Visualize the clustered data
plt.scatter(X[:, 0], X[:, 1], c=labels, s=30, cmap='viridis', alpha=0.5)
plt.title("Fuzzy C-Means Clustering")
plt.xlabel("X")
plt.ylabel("y_true")
plt.show()

# %% [markdown]
# <h2>Spectral Algorithm</h2>

# %%
# Apply spectral clustering
spectral = SpectralClustering(n_clusters=4, random_state=42)
Slabels = spectral.fit_predict(X)

# %%
# Evaluate clustering performance using Adjusted Rand Index
ari = adjusted_rand_score(y_true, Slabels)
silhouette_avg = silhouette_score(X, Slabels)

# Print Adjusted Rand Index
print(f"Adjusted Rand Index: {ari:.4f}")
print(f"Silhouette Score: {silhouette_avg:.4f}")
# Out:
# Adjusted Rand Index: 0.9911
# Silhouette Score: 0.7916

# %%
# Visualize the clustered data
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=labels, s=30, cmap='viridis', alpha=0.5)
plt.title("Spectral Clustering")
plt.xlabel("X")
plt.ylabel("y_true")
plt.show()

# %% [markdown]
# <h2>Agglomerative Algorithm</h2>

# %%
agglo = AgglomerativeClustering(n_clusters=4)
Alabels = agglo.fit_predict(X)

# %%
# Evaluate clustering performance using Adjusted Rand Index
ari = adjusted_rand_score(y_true, Alabels)
silhouette_avg = silhouette_score(X, Alabels)

# Print Adjusted Rand Index
print(f"Adjusted Rand Index: {ari:.4f}")
print(f"Silhouette Score: {silhouette_avg:.4f}")
# Out:
# Adjusted Rand Index: 0.9911
# Silhouette Score: 0.7916

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=labels, s=30, cmap='viridis', alpha=0.5)
plt.title("Agglomerative Clustering")
plt.xlabel("X")
plt.ylabel("y_true")
plt.show()
